# %% [markdown]
# # Open cv Project

# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

# %%
img = "abc.png"
img = cv.imread(img,1)
plt.imshow(img)
cv.imshow('b',img)
plt.imshow(img)
plt.title("oriional image")
cv.waitKey(0)
cv.destroyAllWindows()

# %%
HSV_img = cv.cvtColor(img,cv.COLOR_RGB2HSV)
cv.imshow('b',HSV_img)
plt.imshow(HSV_img)
plt.title('HSV image')
cv.waitKey(0)
cv.destroyAllWindows()

# %%
hue_image = HSV_img[:,:,0]
plt.imshow(hue_image)
plt.title('HUE Image')
# Out:
# Text(0.5, 1.0, 'HUE Image')

# %%
lower_bound = np.array([0,0,0])
upper_bound = np.array([5,255,255])
mask = cv2.inRange(HSV_img , lower_bound, upper_bound)
mask[mask != 0] == [0,0,0]
#result = cv2.bitwise_and(hue_image, hue_image, mask=mask)
plt.imshow(mask)

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load the image
img_path = "abc.png"
img = cv2.imread(img_path)
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# Display the original image
plt.imshow(img_rgb)
plt.title("Original Image")
plt.show()

# Convert the image to HSV
HSV_img = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)

# Define lower and upper bounds for the color range you want to keep
lower_bound = np.array([0, 0, 0])
upper_bound = np.array([5, 255, 255])

# Create a mask
mask = cv2.inRange(HSV_img, lower_bound, upper_bound)

# Set the masked pixels to black [0, 0, 0]
HSV_img[mask == 0] = [0, 0, 0]

# Convert back to RGB for display
result_img = cv2.cvtColor(HSV_img, cv2.COLOR_HSV2RGB)

# Display the result
plt.imshow(result_img)
plt.title("Background Removed")
plt.show()
